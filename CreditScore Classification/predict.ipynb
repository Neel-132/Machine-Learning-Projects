# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')
pd.set_option('display.max_columns', None)
df.shape
# Out:
# (100000, 28)

# %%
df.head(10)
# Out:
#      ID  Customer_ID  Month             Name   Age          SSN Occupation  \
# 0  5634         3392      1    Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2    Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3    Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4    Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5    Aaron Maashoh  23.0  821000265.0  Scientist
# 5  5639         3392      6    Aaron Maashoh  23.0  821000265.0  Scientist
# 6  5640         3392      7    Aaron Maashoh  23.0  821000265.0  Scientist
# 7  5641         3392      8    Aaron Maashoh  23.0  821000265.0  Scientist
# 8  5646         8625      1  Rick Rothackerj  28.0    4075839.0    Teacher
# 9  5647         8625      2  Rick Rothackerj  28.0    4075839.0    Teacher
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ...

# %% [markdown]
# ## Data Description
#
#  - ID: Unique ID of the record
#  - Customer_ID: Unique ID of the customer
#  - Month: Month of the year
#  - Name: The name of the person
#  - Age: The age of the person
#  - SSN: Social Security Number of the person
#  - Occupation: The occupation of the person
#  - Annual_Income: The Annual Income of the person
#  - Monthly_Inhand_Salary: Monthly in-hand salary of the person
#  - Num_Bank_Accounts: The number of bank accounts of the person
#  - Num_Credit_Card: Number of credit cards the person is having
#  - Interest_Rate: The interest rate on the credit card of the person
#  - Num_of_Loan: The number of loans taken by the person from the bank
#  - Type_of_Loan: The types of loans taken by the person from the bank
#  - Delay_from_due_date: The average number of days delayed by the person from the date of payment
#  - Num_of_Delayed_Payment: Number of payments delayed by the person
#  - Changed_Credit_Card: The percentage change in the credit card limit of the person
#  - Num_Credit_Inquiries: The number of credit card inquiries by the person
#  - Credit_Mix: Classification of Credit Mix of the customer
#  - Outstanding_Debt: The outstanding balance of the person
#  - Credit_Utilization_Ratio: The credit utilization ratio of the credit card of the customer
#  - Credit_History_Age: The age of the credit history of the person
#  - Payment_of_Min_Amount: Yes if the person paid the minimum amount to be paid only, otherwise no.
#  - Total_EMI_per_month: The total EMI per month of the person
#  - Amount_invested_monthly: The monthly amount invested by the person
#  - Payment_Behaviour: The payment behaviour of the person
#  - Monthly_Balance: The monthly balance left in the account of the person
#  - Credit_Score: The credit score of the person

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %% [markdown]
# ### There are no null values in the data set

# %%
df['Occupation'].value_counts()
# Out:
# Lawyer           7096
# Engineer         6864
# Architect        6824
# Mechanic         6776
# Scientist        6744
# Accountant       6744
# Developer        6720
# Media_Manager    6720
# Teacher          6672
# Entrepreneur     6648
# Doctor           6568
# Journalist       6536
# Manager          6432
# Musician         6352
# Writer           6304
# Name: Occupation, dtype: int64

# %%
df.nunique()
# Out:
# ID                          100000
# Customer_ID                  12500
# Month                            8
# Name                         10128
# Age                             43
# SSN                          12500
# Occupation                      15
# Annual_Income                12488
# Monthly_Inhand_Salary        13241
# Num_Bank_Accounts               12
# Num_Credit_Card                 12
# Interest_Rate                   34
# Num_of_Loan                     10
# Type_of_Loan                  6261
# Delay_from_due_date             63
# Num_of_Delayed_Payment          26
# Changed_Credit_Limit          3452
# Num_Credit_Inquiries            18
# Credit_Mix                       3
# Outstanding_Debt             12203
# Credit_Utilization_Ratio    100000
# Credit_History_Age             404
# Payment_of_Min_Amount            3
# Total_EMI_per_month          11890
# Amount_invested_monthly      12261
# Payment_Behaviour                6
# Monthly_Balance              98494
# ...

# %% [markdown]
# ### Clearly the ID corresponds to the primary key of the dataset and there are no duplicate entries present.

# %%
Occupation = df['Occupation'].value_counts().tolist()
labels = df['Occupation'].values.tolist()
labels = list(set(labels))
plt.figure(figsize = (15,15))
plt.pie(Occupation, labels = labels, autopct = '%1.2f%%')
plt.show()

# %% [markdown]
# ### Clearly the dataset is very evenly distributed with respect to the Occupation. Every occupation contributes to ~ 7% of the dataset.

# %%
plt.figure(figsize = (10,10))
sns.histplot(data = df, x = 'Age', kde = True, stat = 'probability')
plt.show()

# %% [markdown]
# The distribution of the age is not normal. People mostly with age 20-45 use credit card.

# %%
plt.figure(figsize = (10,10))
sns.histplot(data = df, x = 'Age', hue = 'Credit_Score', kde = True, stat = 'probability', palette = 'husl')
plt.show()

# %%
### The above distribution is pretty uniform with respect to every

# %%
plt.figure(figsize = (20,20))
sns.histplot(data = df, x = 'Annual_Income', kde = True, stat = 'probability')
plt.show()

# %% [markdown]
# #### The distribution is exponential  and trimodal with the peak being at 25000 and at 30000 and 60000.

# %%
plt.figure(figsize = (20,20))
sns.histplot(data = df, x = 'Annual_Income', hue = 'Credit_Score', kde = True, stat = 'probability', palette = 'husl')
plt.show()

# %% [markdown]
#  - The distribution of the annual income of people having good credit score is peaked at 35000
#  - The distribution of the annual income of people having standard credit score is peaked at 12500
#  - The distribution of the annual income of people having poor credit score is peaked at 13500
#
# People with annual income more than 87500 are more likely to have good credit score than poor credit score which is pretty normal.
# Also, everyone are more likely to have standard credit score irrespective of their annual income which is pretty surprising

# %%
plt.figure(figsize = (20,10))
sns.histplot(data = df, x = 'Amount_invested_monthly', kde = True, stat = 'probability')
plt.xticks(np.arange(0, 500, 25))
plt.show()

# %% [markdown]
# ### The distribution of the amount invested monthly is also exponential with the peak being at 25. Also, there is also a pretty high population not investing at all.

# %%
plt.figure(figsize = (20,10))
sns.histplot(data = df, x = 'Amount_invested_monthly', kde = True, hue = 'Credit_Score', stat = 'probability')
plt.xticks(np.arange(0, 500, 25))
plt.show()

# %% [markdown]
#  - From the above plot it is clear that everyone investing atleast 12 have standard credit score
#  - People who aren't investing at all are more likely to have poor credit score which is pretty self-explanatory.
#  - Also, there's this interesting observation that people investing less than 85 are more likely to have poor credit score than good credit score whereas it's the opposite for peole investing more than 85.

# %%
df.tail(10)
# Out:
#            ID  Customer_ID  Month            Name   Age         SSN  \
# 99990  155616        34304      7  Sarah McBridec  28.0  31350942.0
# 99991  155617        34304      8  Sarah McBridec  29.0  31350942.0
# 99992  155622        37932      1           Nicks  24.0  78735990.0
# 99993  155623        37932      2           Nicks  25.0  78735990.0
# 99994  155624        37932      3           Nicks  25.0  78735990.0
# 99995  155625        37932      4           Nicks  25.0  78735990.0
# 99996  155626        37932      5           Nicks  25.0  78735990.0
# 99997  155627        37932      6           Nicks  25.0  78735990.0
# 99998  155628        37932      7           Nicks  25.0  78735990.0
# 99999  155629        37932      8           Nicks  25.0  78735990.0
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 99990  Architect       20002.88            1929.906667               10.0
# ...

# %%
plt.figure(figsize = (20, 10), dpi = 100)
sns.boxplot(data = df, x = 'Occupation', y = 'Num_Bank_Accounts')
plt.yticks(np.arange(0, 15))
plt.show()

# %% [markdown]
# ### The average bank accounts of people ranges from 5 to 6 which is pretty normal.

# %%
plt.figure(figsize = (20, 20))
sns.boxplot(data = df, x = 'Occupation', y = 'Annual_Income')
plt.show()

# %% [markdown]
# ### The annual income is also quite similar for every occupation with the average being between 35000-40000. Also, there are a few outliers with respect to every occupation.

# %%
plt.figure(figsize = (20, 20))
sns.boxplot(data = df, x = 'Credit_Score', y = 'Annual_Income')
plt.show()

# %% [markdown]
# ### So, people with high annual income has high credit score and low income has poor credit score.

# %%
plt.figure(figsize = (20, 20))
sns.boxplot(data = df, x = 'Credit_Score', y = 'Delay_from_due_date')
plt.show()

# %% [markdown]
#  - People with delayed payments between 5 to 15 have good credit score.
#  - People with delayed payments between 10 to 26 have standard credit score.
#  - People with delayed payments between 15 to 45 have poor credit score.

# %%
plt.figure(figsize = (20, 20))
sns.boxplot(data = df, x = 'Credit_Score', y = 'Num_Credit_Card')
plt.show()

# %%
plt.figure(figsize = (20, 20), dpi = 200)
sns.boxplot(data = df,  x = 'Credit_Score', y = 'Amount_invested_monthly')
#plt.xticks(np.arange(0, df['Amount_invested_monthly'].max() + 1, 15 ))
plt.show()

# %% [markdown]
# ## The amount invested monthly doesn't affect credit scores.

# %%
plt.figure(figsize = (20, 20), dpi = 200)
sns.boxplot(data = df,  x = 'Credit_Score', y = 'Outstanding_Debt')
#plt.xticks(np.arange(0, df['Amount_invested_monthly'].max() + 1, 15 ))
plt.show()

# %% [markdown]
# ## The more you owe the less your credit score becomes

# %%
plt.figure(figsize = (20, 20), dpi = 200)
sns.boxplot(data = df,  x = 'Credit_Score', y = 'Num_Credit_Card')
#plt.xticks(np.arange(0, df['Amount_invested_monthly'].max() + 1, 15 ))
plt.show()

# %% [markdown]
# - People having 3 to 5 credit cards have good credit score with the median being at 4.
# - People having 4 to 7 credit cards have standard credit score with median being at 5.
# - People having 5 to 8 credit cards have poor credit score with median being at 7.

# %%
plt.figure(figsize = (20, 20), dpi = 200)
sns.boxplot(data = df,  x = 'Credit_Score', y = 'Monthly_Balance')
#plt.xticks(np.arange(0, df['Amount_invested_monthly'].max() + 1, 15 ))
plt.show()

# %% [markdown]
# ### The more balance you have the better the credit score becomes.

# %%
plt.figure(figsize = (20, 20), dpi = 200)
sns.boxplot(data = df, x = 'Credit_Score', y = 'Total_EMI_per_month')
plt.show()

# %% [markdown]
# ## So, the total Emi per month doesnt contribute to the quality of credit score.

# %%
plt.figure(figsize = (20, 20), dpi = 200)
sns.countplot(data = df, x = 'Month', hue = 'Credit_Score')
plt.show()

# %% [markdown]
# ## Multivariate Analysis

# %%
plt.figure(figsize = (20, 10), dpi = 200)
sns.barplot(data = df, x = 'Occupation', y = 'Annual_Income')
plt.show()

# %% [markdown]
# ### The average income of people of every occupation is almost similar and pretty high with a value of 50000 which is a bit weird

# %%
plt.figure(figsize = (20, 10), dpi = 200)
sns.barplot(data = df, x = 'Occupation', y = 'Annual_Income', hue = 'Credit_Score')
plt.show()

# %% [markdown]
#  - Clearly people with every occupation having a average annual income of more than 65000 has a good credit score
#  - People having a average annual income 50000 has a standard credit score
#  - People having a average annual income of 40000 has a pood credit score

# %%
plt.figure(figsize = (20, 20), dpi = 200)
sns.barplot(data = df,  x = 'Occupation', y = 'Amount_invested_monthly')
plt.show()

# %% [markdown]
# ### The average amount invested monthly is pretty high with a value of 55 for every occupation which is definitely very ususual.

# %%
plt.figure(figsize = (20, 10), dpi = 200)
sns.barplot(data = df,  x = 'Occupation', y = 'Amount_invested_monthly', hue = 'Credit_Score')
plt.show()

# %% [markdown]
# ### From the above barplot we can infer :
#  - People investing 70 on average from every occupation are more likely to have Good credit score.
#  - People investing 55 on average from every occupation are more likely to have Standard credit score.
#  - People investing 48 on average from every occupation are more likely to have Poor credit score.

# %%
plt.figure(figsize = (20, 10), dpi = 200)
sns.barplot(data = df,  x = 'Month', y = 'Outstanding_Debt')
plt.show()

# %% [markdown]
#  ### The outstanding debt of the people on average is pretty same for every month which is 1400.

# %%
plt.figure(figsize = (10, 10))
sns.barplot(data = df,  x = 'Month', y = 'Outstanding_Debt', hue = 'Credit_Score')
plt.show()

# %%
plt.figure(figsize = (20, 20))
sns.barplot(data = df,  x = 'Occupation', y = 'Monthly_Balance', hue = 'Credit_Score')
plt.show()

# %%
plt.figure(figsize = (20, 20))
sns.barplot(data = df,  x = 'Occupation', y = 'Monthly_Balance', hue = 'Credit_Score')
plt.show()

# %%
plt.figure(figsize = (20, 20))
sns.countplot(data = df, x = 'Occupation', hue = 'Payment_of_Min_Amount')
# Out:
# <AxesSubplot: xlabel='Occupation', ylabel='count'>

# %% [markdown]
# ## So, people with every occupation have mostly paid their minimum amount which is pretty evident from the previous plot.
# ## Engineers and Developers are most likely to have paid the minimum amount.

# %% [markdown]
# ## Scatter plots

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %%
del df['Name']

# %%
del df['SSN']

# %%
del df['Customer_ID']

# %%
del df['ID']

# %%
del df['Month']

# %%
def condition(x):
    if x == "Good":
        return 1
    elif x == "Standard":
        return 0
    else:
        return -1

df['Credit_Score'] = df['Credit_Score'].apply(condition)

# %%
df.head()
# Out:
#     Age Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0  23.0  Scientist       19114.12            1824.843333                3.0
# 1  23.0  Scientist       19114.12            1824.843333                3.0
# 2  23.0  Scientist       19114.12            1824.843333                3.0
# 3  23.0  Scientist       19114.12            1824.843333                3.0
# 4  23.0  Scientist       19114.12            1824.843333                3.0
#
#    Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0              4.0            3.0          4.0
# 1              4.0            3.0          4.0
# 2              4.0            3.0          4.0
# 3              4.0            3.0          4.0
# 4              4.0            3.0          4.0
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...                  3.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Age                       100000 non-null  float64
#  1   Occupation                100000 non-null  object
#  2   Annual_Income             100000 non-null  float64
#  3   Monthly_Inhand_Salary     100000 non-null  float64
#  4   Num_Bank_Accounts         100000 non-null  float64
#  5   Num_Credit_Card           100000 non-null  float64
#  6   Interest_Rate             100000 non-null  float64
#  7   Num_of_Loan               100000 non-null  float64
#  8   Type_of_Loan              100000 non-null  object
#  9   Delay_from_due_date       100000 non-null  float64
#  10  Num_of_Delayed_Payment    100000 non-null  float64
#  11  Changed_Credit_Limit      100000 non-null  float64
#  12  Num_Credit_Inquiries      100000 non-null  float64
# ...

# %%
df['Credit_Mix'] = df['Credit_Mix'].apply(condition)

# %%
plt.figure(figsize = (20, 20))
sns.heatmap(df.corr(), annot = True)
plt.tight_layout()
# Out:
# C:\Users\Neela\AppData\Local\Temp\ipykernel_15480\1455482060.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True)

# %%
def transform_payment(x):
    if x == "Yes":
        return 1
    else:
        return 0
df['Payment_of_Min_Amount'] = df['Payment_of_Min_Amount'].apply(transform_payment)

# %%
#df = pd.get_dummies(df, 'Occupation')

# %%
del df['Payment_Behaviour']

# %%
del df['Type_of_Loan']

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Age                       100000 non-null  float64
#  1   Occupation                100000 non-null  object
#  2   Annual_Income             100000 non-null  float64
#  3   Monthly_Inhand_Salary     100000 non-null  float64
#  4   Num_Bank_Accounts         100000 non-null  float64
#  5   Num_Credit_Card           100000 non-null  float64
#  6   Interest_Rate             100000 non-null  float64
#  7   Num_of_Loan               100000 non-null  float64
#  8   Delay_from_due_date       100000 non-null  float64
#  9   Num_of_Delayed_Payment    100000 non-null  float64
#  10  Changed_Credit_Limit      100000 non-null  float64
#  11  Num_Credit_Inquiries      100000 non-null  float64
#  12  Credit_Mix                100000 non-null  int64
# ...

# %%
df['Occupation'].value_counts()
# Out:
# Lawyer           7096
# Engineer         6864
# Architect        6824
# Mechanic         6776
# Scientist        6744
# Accountant       6744
# Developer        6720
# Media_Manager    6720
# Teacher          6672
# Entrepreneur     6648
# Doctor           6568
# Journalist       6536
# Manager          6432
# Musician         6352
# Writer           6304
# Name: Occupation, dtype: int64

# %%
df = pd.get_dummies(df, 'Occupation')
y = df['Credit_Score']
del df['Credit_Score']

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
std_df = sc.fit_transform(df)
std_df1 = sc.fit_transform(df.head(1000))

# %%
from sklearn.manifold import TSNE
tsne = TSNE(perplexity = 50)
tsne_data = tsne.fit_transform(std_df1)
# Out:
# C:\Users\Neela\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\Neela\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
red_df = np.column_stack((tsne_data, y.head(1000)))
red_df = pd.DataFrame(red_df, columns = ('Dim1', 'Dim2', 'Credit_Score'))
sns.scatterplot(data = red_df, x = "Dim1", y = "Dim2", hue = "Credit_Score")
plt.show()

# %%
from sklearn.neighbors import LocalOutlierFactor
clf = LocalOutlierFactor(n_neighbors = 15, contamination = 0.03)
pred = clf.fit_predict(std_df)

# %%
outlier_ind = np.where(pred == -1)
outlier_val = df.iloc[outlier_ind]
outlier_op = y.iloc[outlier_ind]

# %%
outlier = sc.fit_transform(outlier_val)
tsne = TSNE(perplexity = 50)
tsne_data = tsne.fit_transform(outlier)
ol_df = np.column_stack((tsne_data, outlier_op))
ol_df = pd.DataFrame(ol_df, columns = ('Dim1', 'Dim2', 'Credit_Score'))
sns.scatterplot(data = red_df, x = "Dim1", y = "Dim2", hue = "Credit_Score")
plt.show()

# %% [markdown]
# ## Since there is no practical difference in outliers and original dataset clearly, there is no use of outlier removal

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test = train_test_split(std_df,y,
                                   random_state=104, 
                                   test_size=0.25, 
                                   shuffle=True)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### 10 Fold Cross Validation

# %%
from tqdm import tqdm as tqdm
knn = KNeighborsClassifier()
neigh = tqdm(np.arange(1, 31, 2))
cv_acc = []

for n in neigh:
    knn.n_neighbors = n
    cv_sc = cross_val_score(knn, X_train, y_train, scoring = 'accuracy', cv = 10)
    cv_acc.append(np.mean(cv_sc))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 15/15 [02:40<00:00, 10.71s/it]

# %%
for el in range(len(cv_acc)):
    print("10 fold CV accuracy for {} neighbors is {:.2f}%".format(2*el + 1, cv_acc[el] * float(100)))
# Out:
# 10 fold CV accuracy for 1 neighbors is 75.75%
# 10 fold CV accuracy for 3 neighbors is 77.29%
# 10 fold CV accuracy for 5 neighbors is 76.92%
# 10 fold CV accuracy for 7 neighbors is 76.05%
# 10 fold CV accuracy for 9 neighbors is 74.84%
# 10 fold CV accuracy for 11 neighbors is 74.03%
# 10 fold CV accuracy for 13 neighbors is 73.33%
# 10 fold CV accuracy for 15 neighbors is 72.72%
# 10 fold CV accuracy for 17 neighbors is 72.36%
# 10 fold CV accuracy for 19 neighbors is 71.93%
# 10 fold CV accuracy for 21 neighbors is 71.53%
# 10 fold CV accuracy for 23 neighbors is 71.29%
# 10 fold CV accuracy for 25 neighbors is 71.13%
# 10 fold CV accuracy for 27 neighbors is 71.02%
# 10 fold CV accuracy for 29 neighbors is 70.77%

# %%
cv_err = 1 - np.array(cv_acc)
min_n = np.argmin(cv_err)
min_n
# Out:
# 1

# %%
from sklearn.metrics import accuracy_score
knn.n_neighbors = min_n
model = knn.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_pred, y_test)
print("Accuracy for {} neighbors in test data is {:.2f}%".format(2 * min_n + 1, accuracy  * float(100)))
# Out:
# Accuracy for 3 neighbors in test data is 76.12%
